# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("C:/Users/Lenovo/Desktop/DATA_HOTELES_PYTHON.xlsx")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
# eliminamos columnas que no tienen relevancia para el analisis
data = data.drop(['is_canceled'], axis = 1)

# %%
# primer caso de estudio son los huespedes que llevan niños o bebes al hotel
data_niños = data[data["children"]>=1]
data_bebes = data[data["babies"]>=1]
data_bebes_y_niños = data.query("children >=1 or babies >=1")

# %%
data[data.arrival_date_year == 2015]
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# 0       Resort Hotel        342               2015               July
# 1       Resort Hotel        737               2015               July
# 2       Resort Hotel          7               2015               July
# 3       Resort Hotel         13               2015               July
# 4       Resort Hotel         14               2015               July
# ...              ...        ...                ...                ...
# 82958     City Hotel          4               2015             August
# 82959     City Hotel          0               2015            October
# 82960     City Hotel          1               2015           December
# 82974     City Hotel          0               2015           December
# 103758    City Hotel          0               2015            October
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# ...

# %%
data_bebes_y_niños = data.query("children >=1 and babies >=1")
data_bebes_y_niños
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# 272     Resort Hotel         87               2015               July
# 521     Resort Hotel        106               2015               July
# 951     Resort Hotel        116               2015             August
# 998     Resort Hotel         81               2015             August
# 1081    Resort Hotel         47               2015             August
# ...              ...        ...                ...                ...
# 117708    City Hotel        129               2017             August
# 117758    City Hotel        169               2017             August
# 118257    City Hotel        288               2017             August
# 118265    City Hotel        208               2017             August
# 119106    City Hotel          0               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 272                           28                         10
# ...

# %%
pd.options.display.max_columns = 40

# %%
data_bebes_y_niños
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# 272     Resort Hotel         87               2015               July
# 521     Resort Hotel        106               2015               July
# 951     Resort Hotel        116               2015             August
# 998     Resort Hotel         81               2015             August
# 1081    Resort Hotel         47               2015             August
# ...              ...        ...                ...                ...
# 117708    City Hotel        129               2017             August
# 117758    City Hotel        169               2017             August
# 118257    City Hotel        288               2017             August
# 118265    City Hotel        208               2017             August
# 119106    City Hotel          0               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 272                           28                         10
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
data_julio = data.query('arrival_date_month == "July" or arrival_date_month == "August"')
data_julio
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# 0       Resort Hotel        342               2015               July
# 1       Resort Hotel        737               2015               July
# 2       Resort Hotel          7               2015               July
# 3       Resort Hotel         13               2015               July
# 4       Resort Hotel         14               2015               July
# ...              ...        ...                ...                ...
# 119385    City Hotel         23               2017             August
# 119386    City Hotel        102               2017             August
# 119387    City Hotel         34               2017             August
# 119388    City Hotel        109               2017             August
# 119389    City Hotel        205               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 0                             27                          1
# ...

# %%
data_julio_2015 = data.query('arrival_date_month == "July" and arrival_date_year == 2015')
data_julio_2015
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 0      Resort Hotel        342               2015               July
# 1      Resort Hotel        737               2015               July
# 2      Resort Hotel          7               2015               July
# 3      Resort Hotel         13               2015               July
# 4      Resort Hotel         14               2015               July
# ...             ...        ...                ...                ...
# 76621    City Hotel          1               2015               July
# 76625    City Hotel        210               2015               July
# 76626    City Hotel          1               2015               July
# 76627    City Hotel        209               2015               July
# 76628    City Hotel        210               2015               July
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 0                            27                          1
# ...

# %%
data.query('arrival_date_month in ["july", "January"]')
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# 3738    Resort Hotel        109               2016            January
# 3739    Resort Hotel        109               2016            January
# 3740    Resort Hotel          2               2016            January
# 3741    Resort Hotel         88               2016            January
# 3742    Resort Hotel         20               2016            January
# ...              ...        ...                ...                ...
# 105403    City Hotel         91               2017            January
# 105410    City Hotel         18               2017            January
# 105512    City Hotel         23               2017            January
# 105525    City Hotel          5               2017            January
# 106561    City Hotel         11               2017            January
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 3738                           1                          1
# ...

# %%
# buscar un texto o palabra dentro de una cadena de texto
data.query('hotel.str.contains("City")', engine='python')
# Out:
#              hotel  lead_time  arrival_date_year arrival_date_month  \
# 40060   City Hotel          6               2015               July
# 40061   City Hotel         88               2015               July
# 40062   City Hotel         65               2015               July
# 40063   City Hotel         92               2015               July
# 40064   City Hotel        100               2015               July
# ...            ...        ...                ...                ...
# 119385  City Hotel         23               2017             August
# 119386  City Hotel        102               2017             August
# 119387  City Hotel         34               2017             August
# 119388  City Hotel        109               2017             August
# 119389  City Hotel        205               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 40060                         27                          1
# ...

# %%
data[(data["hotel"] == 'City Hotel') & (data["lead_time"]>=100)]
# Out:
#              hotel  lead_time  arrival_date_year arrival_date_month  \
# 40064   City Hotel        100               2015               July
# 40086   City Hotel        106               2015               July
# 40096   City Hotel        100               2015               July
# 40099   City Hotel        111               2015               July
# 40116   City Hotel        117               2015               July
# ...            ...        ...                ...                ...
# 119382  City Hotel        135               2017             August
# 119383  City Hotel        164               2017             August
# 119386  City Hotel        102               2017             August
# 119388  City Hotel        109               2017             August
# 119389  City Hotel        205               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 40064                         27                          2
# ...

# %%
data.loc[data["hotel"] == "City Hotel", ["precio", "stays_in_week_nights", "hotel"]]
# Out:
#         precio  stays_in_week_nights       hotel
# 40060     0.00                     2  City Hotel
# 40061    76.50                     4  City Hotel
# 40062    68.00                     4  City Hotel
# 40063    76.50                     4  City Hotel
# 40064    76.50                     2  City Hotel
# ...        ...                   ...         ...
# 119385   96.14                     5  City Hotel
# 119386  225.43                     5  City Hotel
# 119387  157.71                     5  City Hotel
# 119388  104.40                     5  City Hotel
# 119389  151.20                     7  City Hotel
#
# [79330 rows x 3 columns]

# %%
data.describe()
# Out:
#            lead_time  arrival_date_year  arrival_date_week_number  \
# count  119390.000000      119390.000000             119390.000000
# mean      104.011416        2016.156554                 27.165173
# std       106.863097           0.707476                 13.605138
# min         0.000000        2015.000000                  1.000000
# 25%        18.000000        2016.000000                 16.000000
# 50%        69.000000        2016.000000                 28.000000
# 75%       160.000000        2017.000000                 38.000000
# max       737.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count              119390.000000            119390.000000
# mean                   15.798241                 0.927599
# std                     8.780829                 0.998613
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# ...

# %%
data.adults.sum()
# Out:
# 221636

# %%
data_por_año = data.groupby("arrival_date_year").sum()
data_por_año2 = data.loc[data["arrival_date_year"] == 2015, ["hotel", 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'precio']]

# %%
data_por_año2 = data_por_año2.groupby("hotel").sum()
data_por_año2
# Out:
#               stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# hotel
# City Hotel                      10375                 27124   24385     512.0
# Resort Hotel                    10075                 27014   15877     845.0
#
#               babies      precio
# hotel
# City Hotel        84  1174694.31
# Resort Hotel     139   742884.31
